# %% [markdown]
# # Overwatch Season 12 Data Analysis

# %% [markdown]
# ## What is Overwatch?

# %% [markdown]
# Overwatch is a team-based multiplayer first-person shooter game developed and published by Blizzard Entertainment, which was released in 2016. You can play Overwatch on PC, PS4, and Xbox one!
#
# In game, Overwatch puts players into two teams of six, divided into various roles such as DPS (Damage Per Second), Tank and Support. Players are expected to work together to secure and defend control points, escort a payload across the map within a set time, or a combination of both. Like League of Legends, players can gain cosmetic rewards that do not affect gameplay and there is a competitive mode which players can rise up the ranks.
#
# Overwatch has grown to be one of the most popular online games, with over 40 million players as of 2018. It has a significant presence in the Esports industry with the Overwatch League, which runs from January-September and is divided into 4 different "stages" ending with the grand finals. However, with the rise of Battle Royale games such as Fortnite and PUBG, Overwatch has died a little, yet it is still going strong!

# %% [markdown]
# #### About this Project

# %% [markdown]
# This is a project I had originally started last year during Overwatch Season 12 where I wanted to see my performance compared to previous seasons, unfortunately a lot of this information is incomplete and I hope to do another version of this project once role-lock is put into place in the newest competitive season. This is just a simple analysis of my performance for a brief time period during Season 12, which took place during August 2018-October 2018.
#
# For context, Overwatch is one of my favorite games to play online, which is another reason why I decided to do this project.

# %%
#Let's import some necessary Libraries 
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

OW_trends312 = pd.read_csv(r'...Season3-12WinLossData.csv')

# %%
#Let's take a look at this data that I imported so far for the earlier seasons. 
OW_trends312.head()
# Out:
#       Season  Placed   Ended  Unnamed: 3  SEASON High   Total WINS  \
# 0  Season 3     2010  1649.0         NaN          2275        15.0
# 1   Season 4    1645  1379.0         NaN          1668        98.0
# 2   Season 5    1350  1520.0         NaN          1920       251.0
# 3   Season 6    1773  1845.0         NaN          1998       223.0
# 4   Season 7    1950  2084.0         NaN          2107       106.0
#
#    Total Losses  Total ties  Total played
# 0          25.0         2.0          42.0
# 1         101.0         7.0         206.0
# 2         258.0        22.0         531.0
# 3         191.0        18.0         432.0
# 4         110.0        10.0         226.0

# %% [markdown]
# # Looking at Earlier Season Data First

# %% [markdown]
# Right here, we have the numbers for my performance for the first 7 seasons, with the start aka where I was placed after completing the first 10 matches of the season. This table is nice, but we can take a look at this using a line graph, where I'll be looking at my performance in the first few seasons I played competitive in.
#
# The question I'll be trying to answer from looking at this data comparing between earlier seasons to the most recent season that I have recorded is:
#     <ul>
#     <li>Is there a significant difference in SR losses and gains in the earlier seasons, compared to the
#         most recent season?</li>
#     <li>The timing of when I play/join the season, does that have an affect on my SR?</li>
#     </ul>
# It should be noted that the timing is a rough estimation of when I had that SR, generally I end up peaking and hitting my Season High during the midpoint of the season.

# %%
# Y- Axis: SR 
# X- Axis: Days During Season (Season Lasts APPRX 90 days)
#Lines would should performance over time

Season3x = [60,80,90]
Season3y = [2010,2275,1649]
plt.plot(Season3x, Season3y, label = "Season 3")

Season4x = [5,15,90]
Season4y = [1645,1668,1379]
plt.plot(Season4x, Season4y, label = "Season 4")

Season5x = [10,60,90]
Season5y = [1350,1920,1520]
plt.plot(Season5x, Season5y, label = "Season 5")

plt.title('Overwatch Performance Season 3-5')
plt.xlabel('Days in the Season')
plt.ylabel('SR Rating')
plt.legend()
plt.show()

# %% [markdown]
# When I initially first started playing Overwatch, the competitive season was in the middle of its run, and there are requirements in order to play in the competitive season. The requirements in order to play was that you need to be at level 25 overall, then you would have to place by playing 10 matches, from there your ranking would be determined.
#
# There are several ranks in Overwatch Competitive starting with Bronze and going all the way up to Top 500.
#
# For this first graph this shows my SR rating going from the starting point all to the highest point where I peaked in the season all the way to the end point of the season. With Season 3, I started in Gold (2000-2500 SR), and unfortunately deranked to Silver, which was expected since I had no idea what I was doing in competitive, and instantly locked onto a role as opposed to learning more roles. Let's take a look at the win:lose ratio in the form of pie graphs.

# %%
#Creating a pie graph *Currently in Progress* 
#Labels: Seasons 
#Size for Seasons:Length of Season 
#Outcome: Win, Lose, Tie
#Outcome Size: Number of Wins, Losses and Ties 

#Season is the initial group
Season = ['Season 3', 'Season 4', 'Season 5']
Season_Size = [90,90,90]

#Outcome is the subgroup
Outcome = ['Win, Loss','Tie','Win, Loss','Tie',
           'Win, Loss','Tie']
Outcome_Size = [15,25,2,98,101,7,251,258,22]

#Creating Colors
S3, S4, S5=[plt.cm.Blues,plt.cm.Reds,plt.cm.Greens]

#Begin Plotting Outer ring
fig,ax = plt.subplots()
ax.axis('equal')
Spie, _ = ax.pie(Season_Size, radius=2.0,labels=Season, 
                 colors=[S3(90),S4(90),S5(90)])
plt.setp(Spie,width=0.3,edgecolor='white')

plt.title("Win-Lose Rates in Early Competitive Seasons")
plt.show()

# %% [markdown]
# # Looking at the more recent performance

# %% [markdown]
# As with all games to keep up and in an effort to bring something new, things change. In the more recent seasons of Overwatch ,such as Season 6 onward, the competitive instead lasts only 2 months as opposed to 3 months. This meant more competitive seasons took place as well as a small down-time period when it would come to the "in-between" time in between competitive seasons. Let's take a look at the more recent competitive seasons and my performance.

# %%
#Looking at the more recent seasons 
OW_trends312.tail()
# Out:
#       Season  Placed   Ended  Unnamed: 3  SEASON High   Total WINS  \
# 5   Season 8    2005  2080.0         NaN          2251       100.0
# 6   Season 9    2003  1942.0         NaN          2241        21.0
# 7  Season 10    1890  1844.0         NaN          1930        10.0
# 8  Season 11    1905  2002.0         NaN          2110        96.0
# 9  Season 12    1830     NaN         NaN          2258         NaN
#
#    Total Losses  Total ties  Total played
# 5          98.0         4.0         202.0
# 6          25.0         1.0          47.0
# 7          13.0         0.0          23.0
# 8          92.0         6.0         194.0
# 9           NaN         NaN           NaN

# %%
# Y- Axis: SR 
# X- Axis: Days During Season (Season Lasts APPRX 60 days)
#Lines would should performance over time

Season8x = [5,30,60]
Season8y = [2005,2251,2080]
plt.plot(Season8x, Season8y, label = "Season 8")

Season9x = [10,20,60]
Season9y = [2003,2241,1942]
plt.plot(Season9x, Season9y, label = "Season 9")

Season10x = [25,40,60]
Season10y = [1890,1930,1844]
plt.plot(Season10x, Season10y, label = "Season 10")

Season11x = [5,20,60]
Season11y = [1905,2110,2002]
plt.plot(Season11x, Season11y, label = "Season 11")

Season12x = [10,20,60]
Season12y = [1830,2258,1910]
plt.plot(Season12x, Season12y, label = "Season 12")

Season5x = [10,60,90]
Season5y = [1350,1920,1520]
plt.plot(Season5x, Season5y, label = "Season 5")

plt.title('Overwatch Performance Season 8-12 VS Season 5 ')
plt.xlabel('Days in the Season')
plt.ylabel('SR Rating')
plt.legend()
plt.show()

# %%
#PIE CHART FOR RECENT DATA WORK IN PROGRESS

# %% [markdown]
# Just by looking at this line graph, the starting point for each season is significantly higher than compared to my lowest point in the Overwatch competitive season in Season 5. Interestingly enough, the later in the season I started my performance did not suffer as much later into the season as compared to the other seasons. An example of this is with Season 10, the season I did not play as much, but this is not the case when it came to Season 11. Season 11 started at the same point with everything else, but the decline in SR was not as bad.
#
# There are other factors that can contribute to this. One of which is the roles that were chosen. However, it should be noted that there is no role data for anything prior to Season 12.

# %% [markdown]
# # Role Data

# %% [markdown]
# As mentioned previously, Overwatch is a team game where players can choose different roles such as DPS, Tank and Support. Unfortunately, most people have a tendency to go after DPS leaving those who do not pick on time to fill in Tank and Support, which leads to people not picking Tank or Support. (Sometimes!)
#
# With this being the case, I usually end up filling in a role, which usually means a Tank or support.

# %%
#Preparing the Role Data 
OWRoles = pd.read_csv(r')
